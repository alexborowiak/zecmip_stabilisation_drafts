# %%
import xarray as xr
import numpy as np

import matplotlib.pyplot as plt

import os, sys
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.10/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33187 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:36431' processes=7 threads=7, memory=32.00 GiB>

# %%
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'PhD'))

# %%
import constants

# %%
constants.ZECMIP_DIR
# Out:
# '/g/data/oi10/replicas/CMIP6/C4MIP'

# %%
os.listdir(constants.ZECMIP_LOCAL_DIR)
# Out:
# ['regridded', 'original']

# %%
ZEC_ORIGINAL_PATH = os.path.join(constants.ZECMIP_LOCAL_DIR, 'original', 'A1')

# %%
model_fnames = os.listdir(ZEC_ORIGINAL_PATH); model_fnames
# Out:
# ['CanESM5.nc',
#  'UKESM1-0-LL.nc',
#  'NorESM2-LM.nc',
#  'GFDL-ESM4.nc',
#  'MPI-ESM1-2-LR.nc',
#  'CESM2.nc',
#  'MIROC-ES2L.nc',
#  'GISS-E2-1-G-CC.nc']

# %%
to_concat = []
for fname in model_fnames:
    ds = xr.open_dataset(os.path.join(ZEC_ORIGINAL_PATH, fname), use_cftime=True)
    to_concat.append(ds)

# %%
for ds in to_concat:
    print(str(ds.model.values[0]), len(ds.time.values), sep=' : ')
# Out:
# CanESM5 : 100
# UKESM1-0-LL : 330
# NorESM2-LM : 100
# GFDL-ESM4 : 200
# MPI-ESM1-2-LR : 185
# CESM2 : 150
# MIROC-ES2L : 248
# GISS-E2-1-G-CC : 180

# %%
NOR_PAHT = '/g/data/oi10/replicas/CMIP6/C4MIP/NCC/NorESM2-LM/esm-1pct-brch-1000PgC/r1i1p1f1/Amon/tas/gn/v20191108'

# %%
nor_ds = xr.open_mfdataset(os.path.join(NOR_PAHT, '*.nc'), use_cftime=True)

# %%
nor_ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1200, bnds: 2, lat: 96, lon: 144)
# Coordinates:
#   * time       (time) object 0067-01-16 12:00:00 ... 0166-12-16 12:00:00
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#   * lon        (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     height     float64 2.0
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object dask.array<chunksize=(120, 2), meta=np.ndarray>
#     lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(120, 96, 2), meta=np.ndarray>
#     lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(120, 144, 2), meta=np.ndarray>
#     tas        (time, lat, lon) float32 dask.array<chunksize=(120, 96, 144), meta=np.ndarray>
# Attributes: (12/49)
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               C4MIP CDRMIP
#     branch_method:             Hybrid-restart from year 0067-01-01 of 1pctCO2
# ...

# %%
print(len(np.unique(nor_ds.time.dt.year.values)))
# Out:
# 100

# %%
print(len(nor_ds.time.values))
# Out:
# 1200

# %%
for t in nor_ds.time.values:
    print(t)
# Out:
# 0067-01-16 12:00:00
# 0067-02-15 00:00:00
# 0067-03-16 12:00:00
# 0067-04-16 00:00:00
# 0067-05-16 12:00:00
# 0067-06-16 00:00:00
# 0067-07-16 12:00:00
# 0067-08-16 12:00:00
# 0067-09-16 00:00:00
# 0067-10-16 12:00:00
# 0067-11-16 00:00:00
# 0067-12-16 12:00:00
# 0068-01-16 12:00:00
# 0068-02-15 00:00:00
# 0068-03-16 12:00:00
# 0068-04-16 00:00:00
# 0068-05-16 12:00:00
# 0068-06-16 00:00:00
# 0068-07-16 12:00:00
# 0068-08-16 12:00:00
# 0068-09-16 00:00:00
# 0068-10-16 12:00:00
# 0068-11-16 00:00:00
# 0068-12-16 12:00:00
# 0069-01-16 12:00:00
# 0069-02-15 00:00:00
# 0069-03-16 12:00:00
# 0069-04-16 00:00:00
# 0069-05-16 12:00:00
# 0069-06-16 00:00:00
# 0069-07-16 12:00:00
# 0069-08-16 12:00:00
# 0069-09-16 00:00:00
# 0069-10-16 12:00:00
# 0069-11-16 00:00:00
# 0069-12-16 12:00:00
# 0070-01-16 12:00:00
# 0070-02-15 00:00:00
# 0070-03-16 12:00:00
# 0070-04-16 00:00:00
# 0070-05-16 12:00:00
# 0070-06-16 00:00:00
# 0070-07-16 12:00:00
# 0070-08-16 12:00:00
# 0070-09-16 00:00:00
# ...
